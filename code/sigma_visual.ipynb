# %%
import pandas as pd

# %%
tfidf=pd.read_csv('../data/describe_text_TFIDF.csv',encoding='ISO-8859-1')

# %%
tfidf.rename(columns={'Unnamed: 0':'Word','sort(colSums(as.matrix(describe_text_dtm_tfidf2)), decreasing = TRUE)':'TF-IDF'},inplace=True)

# %%
visual=tfidf.head(10)

# %%
visual.plot.bar(x='Word',y='TF-IDF',subplots=True,rot=0,figsize=(20,16),color='royalblue')
# Out:
# array([<AxesSubplot:title={'center':'TF-IDF'}, xlabel='Word'>],
#       dtype=object)
